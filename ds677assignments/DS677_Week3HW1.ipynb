# %% [markdown]
# <a href="https://colab.research.google.com/github/jeet1912/ms/blob/main/ds677assignments/DS677_Week3HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week3 Homework1 Image Classification

# %% [markdown]
# # Check GPU Type

# %%
# !nvidia-smi
# Out:
# Thu Sep 12 18:17:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Download Data

# %%
# !pip install gdown --upgrade
# !gdown --id '19ZlT0qm-3rdMRe60ya25xiN-ELOohr8M' --output data.zip
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.1.0
#     Uninstalling gdown-5.1.0:
#       Successfully uninstalled gdown-5.1.0
# Successfully installed gdown-5.2.0
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=19ZlT0qm-3rdMRe60ya25xiN-ELOohr8M
# From (redirected): https://drive.google.com/uc?id=19ZlT0qm-3rdMRe60ya25xiN-ELOohr8M&confirm=t&uuid=19556538-6ccb-431d-9471-42281c40860f
# To: /content/data.zip
# 100% 1.03G/1.03G [00:23<00:00, 43.3MB/s]

# %%
! unzip data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/train/5_1294.jpg
#   inflating: data/train/2_237.jpg
#   inflating: data/train/5_908.jpg
#   inflating: data/train/2_223.jpg
#   inflating: data/train/7_5.jpg
#   inflating: data/train/9_286.jpg
#   inflating: data/train/5_1280.jpg
#   inflating: data/train/10_97.jpg
#   inflating: data/train/6_161.jpg
#   inflating: data/train/3_756.jpg
#   inflating: data/train/2_545.jpg
#   inflating: data/train/0_695.jpg
#   inflating: data/train/3_811.jpg
#   inflating: data/train/2_1150.jpg
#   inflating: data/train/9_319.jpg
#   inflating: data/train/5_883.jpg
#   inflating: data/train/3_37.jpg
#   inflating: data/train/4_448.jpg
#   inflating: data/train/5_897.jpg
#   inflating: data/train/3_23.jpg
#   inflating: data/train/2_1144.jpg
#   inflating: data/train/8_678.jpg
#   inflating: data/train/3_805.jpg
#   inflating: data/train/5_129.jpg
#   inflating: data/train/9_443.jpg
#   inflating: data/train/8_650.jpg
#   inflating: data/train/4_312.jpg
#   inflating: data/train/5_101.jpg
#   inflating: data/train/0_736.jpg
#   inflating: data/train/3_193.jpg
#   inflating: data/train/1_243.jpg
#   inflating: data/train/2_380.jpg
#   inflating: data/train/5_667.jpg
#   inflating: data/train/4_474.jpg
#   inflating: data/train/8_136.jpg
#   inflating: data/train/5_1323.jpg
#   inflating: data/train/9_325.jpg
#   inflating: data/train/8_122.jpg
#   inflating: data/train/9_331.jpg
#   inflating: data/train/3_187.jpg
#   inflating: data/train/1_257.jpg
#   inflating: data/train/2_394.jpg
#   inflating: data/train/5_673.jpg
#   inflating: data/train/4_460.jpg
#   inflating: data/train/4_306.jpg
#   inflating: data/train/3_839.jpg
#   inflating: data/train/5_115.jpg
#   inflating: data/train/0_722.jpg
#   inflating: data/train/4_16.jpg
#   inflating: data/train/2_1178.jpg
#   inflating: data/train/9_457.jpg
#   inflating: data/train/8_644.jpg
#   inflating: data/train/2_1193.jpg
#   inflating: data/train/2_419.jpg
#   inflating: data/train/0_911.jpg
#   inflating: data/train/5_698.jpg
#   inflating: data/train/9_1027.jpg
#   inflating: data/train/5_840.jpg
#   inflating: data/train/9_1033.jpg
#   inflating: data/train/3_178.jpg
#   inflating: data/train/5_854.jpg
#   inflating: data/train/0_905.jpg
#   inflating: data/train/2_1187.jpg
#   inflating: data/train/2_425.jpg
#   inflating: data/train/3_636.jpg
#   inflating: data/train/1_3.jpg
#   inflating: data/train/7_212.jpg
#   inflating: data/train/9_480.jpg
#   inflating: data/train/8_693.jpg
#   inflating: data/train/3_150.jpg
#   inflating: data/train/1_280.jpg
#   inflating: data/train/2_343.jpg
#   inflating: data/train/3_144.jpg
#   inflating: data/train/5_868.jpg
#   inflating: data/train/1_294.jpg
#   inflating: data/train/2_357.jpg
#   inflating: data/train/9_494.jpg
#   inflating: data/train/8_687.jpg
#   inflating: data/train/2_431.jpg
#   inflating: data/train/3_622.jpg
#   inflating: data/train/0_939.jpg
#   inflating: data/train/7_206.jpg
#   inflating: data/train/5_459.jpg
#   inflating: data/train/7_53.jpg
#   inflating: data/train/2_1434.jpg
#   inflating: data/train/10_226.jpg
#   inflating: data/train/8_308.jpg
#   inflating: data/train/10_540.jpg
#   inflating: data/train/2_1352.jpg
#   inflating: data/train/0_508.jpg
#   inflating: data/train/2_800.jpg
#   inflating: data/train/2_814.jpg
#   inflating: data/train/4_138.jpg
#   inflating: data/train/9_669.jpg
#   inflating: data/train/2_1346.jpg
#   inflating: data/train/10_554.jpg
#   inflating: data/train/7_47.jpg
#   inflating: data/train/10_232.jpg
#   inflating: data/train/2_1420.jpg
#   inflating: data/train/5_1109.jpg
#   inflating: data/train/2_1408.jpg
#   inflating: data/train/9_127.jpg
#   inflating: data/train/9_42.jpg
#   inflating: data/train/5_1121.jpg
#   inflating: data/train/8_334.jpg
#   inflating: data/train/4_676.jpg
#   inflating: data/train/5_465.jpg
#   inflating: data/train/0_252.jpg
#   inflating: data/train/2_182.jpg
#   inflating: data/train/3_391.jpg
#   inflating: data/train/0_534.jpg
#   inflating: data/train/5_303.jpg
#   inflating: data/train/4_110.jpg
#   inflating: data/train/8_452.jpg
#   inflating: data/train/9_641.jpg
#   inflating: data/train/0_66.jpg
#   inflating: data/train/9_899.jpg
#   inflating: data/train/8_446.jpg
#   inflating: data/train/9_655.jpg
#   inflating: data/train/0_72.jpg
#   inflating: data/train/10_568.jpg
#   inflating: data/train/0_520.jpg
#   inflating: data/train/5_317.jpg
#   inflating: data/train/2_828.jpg
#   inflating: data/train/4_104.jpg
#   inflating: data/train/4_662.jpg
#   inflating: data/train/5_471.jpg
#   inflating: data/train/0_246.jpg
#   inflating: data/train/2_196.jpg
#   inflating: data/train/3_385.jpg
#   inflating: data/train/9_133.jpg
#   inflating: data/train/5_1135.jpg
#   inflating: data/train/9_56.jpg
#   inflating: data/train/8_320.jpg
#   inflating: data/train/7_90.jpg
#   inflating: data/train/4_689.jpg
#   inflating: data/train/9_1225.jpg
#   inflating: data/train/3_408.jpg
#   inflating: data/train/0_99.jpg
#   inflating: data/train/9_866.jpg
#   inflating: data/train/10_583.jpg
#   inflating: data/train/2_1391.jpg
#   inflating: data/train/9_872.jpg
#   inflating: data/train/2_1385.jpg
#   inflating: data/train/10_597.jpg
#   inflating: data/train/2_169.jpg
#   inflating: data/train/4_845.jpg
#   inflating: data/train/9_1231.jpg
#   inflating: data/train/7_84.jpg
#   inflating: data/train/0_291.jpg
#   inflating: data/train/2_141.jpg
#   inflating: data/train/3_352.jpg
#   inflating: data/train/9_1219.jpg
#   inflating: data/train/9_81.jpg
#   inflating: data/train/8_491.jpg
#   inflating: data/train/9_682.jpg
#   inflating: data/train/3_1.jpg
#   inflating: data/train/6_203.jpg
#   inflating: data/train/3_434.jpg
#   inflating: data/train/2_627.jpg
#   inflating: data/train/6_217.jpg
#   inflating: data/train/3_420.jpg
#   inflating: data/train/2_633.jpg
#   inflating: data/train/8_485.jpg
#   inflating: data/train/9_696.jpg
#   inflating: data/train/9_95.jpg
#   inflating: data/train/0_285.jpg
#   inflating: data/train/2_155.jpg
#   inflating: data/train/3_346.jpg
#   inflating: data/train/9_697.jpg
#   inflating: data/train/8_484.jpg
#   inflating: data/train/2_632.jpg
#   inflating: data/train/3_421.jpg
#   inflating: data/train/6_216.jpg
#   inflating: data/train/3_347.jpg
#   inflating: data/train/2_154.jpg
#   inflating: data/train/0_284.jpg
#   inflating: data/train/9_94.jpg
#   inflating: data/train/9_80.jpg
#   inflating: data/train/9_1218.jpg
#   inflating: data/train/3_353.jpg
#   inflating: data/train/2_140.jpg
#   inflating: data/train/0_290.jpg
#   inflating: data/train/2_626.jpg
#   inflating: data/train/3_435.jpg
#   inflating: data/train/6_202.jpg
#   inflating: data/train/3_0.jpg
#   inflating: data/train/9_683.jpg
#   inflating: data/train/8_490.jpg
#   inflating: data/train/10_596.jpg
#   inflating: data/train/2_1384.jpg
#   inflating: data/train/9_873.jpg
#   inflating: data/train/7_85.jpg
#   inflating: data/train/9_1230.jpg
#   inflating: data/train/4_844.jpg
#   inflating: data/train/2_168.jpg
#   inflating: data/train/9_1224.jpg
#   inflating: data/train/4_688.jpg
#   inflating: data/train/7_91.jpg
#   inflating: data/train/2_1390.jpg
#   inflating: data/train/10_582.jpg
#   inflating: data/train/9_867.jpg
#   inflating: data/train/0_98.jpg
#   inflating: data/train/3_409.jpg
#   inflating: data/train/4_105.jpg
#   inflating: data/train/2_829.jpg
#   inflating: data/train/5_316.jpg
#   inflating: data/train/0_521.jpg
#   inflating: data/train/10_569.jpg
#   inflating: data/train/0_73.jpg
#   inflating: data/train/9_654.jpg
#   inflating: data/train/8_447.jpg
#   inflating: data/train/8_321.jpg
#   inflating: data/train/9_57.jpg
#   inflating: data/train/5_1134.jpg
#   inflating: data/train/9_132.jpg
#   inflating: data/train/3_384.jpg
#   inflating: data/train/2_197.jpg
#   inflating: data/train/0_247.jpg
#   inflating: data/train/5_470.jpg
#   inflating: data/train/4_663.jpg
#   inflating: data/train/3_390.jpg
#   inflating: data/train/2_183.jpg
#   inflating: data/train/0_253.jpg
#   inflating: data/train/5_464.jpg
#   inflating: data/train/4_677.jpg
#   inflating: data/train/8_335.jpg
#   inflating: data/train/5_1120.jpg
#   inflating: data/train/9_43.jpg
#   inflating: data/train/9_126.jpg
#   inflating: data/train/2_1409.jpg
#   inflating: data/train/9_898.jpg
#   inflating: data/train/0_67.jpg
#   inflating: data/train/9_640.jpg
#   inflating: data/train/8_453.jpg
#   inflating: data/train/4_111.jpg
#   inflating: data/train/5_302.jpg
#   inflating: data/train/0_535.jpg
#   inflating: data/train/10_555.jpg
#   inflating: data/train/2_1347.jpg
#   inflating: data/train/9_668.jpg
#   inflating: data/train/4_139.jpg
#   inflating: data/train/2_815.jpg
#   inflating: data/train/5_1108.jpg
#   inflating: data/train/2_1421.jpg
#   inflating: data/train/10_233.jpg
#   inflating: data/train/7_46.jpg
#   inflating: data/train/8_309.jpg
#   inflating: data/train/10_227.jpg
#   inflating: data/train/2_1435.jpg
#   inflating: data/train/7_52.jpg
#   inflating: data/train/5_458.jpg
#   inflating: data/train/2_801.jpg
#   inflating: data/train/0_509.jpg
#   inflating: data/train/2_1353.jpg
#   inflating: data/train/10_541.jpg
#   inflating: data/train/2_356.jpg
#   inflating: data/train/1_295.jpg
#   inflating: data/train/5_869.jpg
#   inflating: data/train/3_145.jpg
#   inflating: data/train/7_207.jpg
#   inflating: data/train/0_938.jpg
#   inflating: data/train/3_623.jpg
#   inflating: data/train/2_430.jpg
#   inflating: data/train/8_686.jpg
#   inflating: data/train/9_495.jpg
#   inflating: data/train/8_692.jpg
#   inflating: data/train/9_481.jpg
#   inflating: data/train/7_213.jpg
#   inflating: data/train/1_2.jpg
#   inflating: data/train/3_637.jpg
#   inflating: data/train/2_424.jpg
#   inflating: data/train/2_342.jpg
#   inflating: data/train/1_281.jpg
#   inflating: data/train/3_151.jpg
#   inflating: data/train/5_855.jpg
#   inflating: data/train/3_179.jpg
#   inflating: data/train/9_1032.jpg
#   inflating: data/train/2_1186.jpg
#   inflating: data/train/0_904.jpg
#   inflating: data/train/0_910.jpg
#   inflating: data/train/2_418.jpg
#   inflating: data/train/2_1192.jpg
#   inflating: data/train/5_841.jpg
#   inflating: data/train/9_1026.jpg
#   inflating: data/train/5_699.jpg
#   inflating: data/train/4_461.jpg
#   inflating: data/train/5_672.jpg
#   inflating: data/train/2_395.jpg
#   inflating: data/train/1_256.jpg
#   inflating: data/train/3_186.jpg
#   inflating: data/train/9_330.jpg
#   inflating: data/train/8_123.jpg
#   inflating: data/train/8_645.jpg
#   inflating: data/train/9_456.jpg
#   inflating: data/train/2_1179.jpg
#   inflating: data/train/4_17.jpg
#   inflating: data/train/0_723.jpg
#   inflating: data/train/5_114.jpg
#   inflating: data/train/3_838.jpg
#   inflating: data/train/4_307.jpg
#   inflating: data/train/0_737.jpg
#   inflating: data/train/5_100.jpg
#   inflating: data/train/4_313.jpg
#   inflating: data/train/8_651.jpg
#   inflating: data/train/9_442.jpg
#   inflating: data/train/9_324.jpg
#   inflating: data/train/5_1322.jpg
#   inflating: data/train/8_137.jpg
#   inflating: data/train/4_475.jpg
#   inflating: data/train/5_666.jpg
#   inflating: data/train/2_381.jpg
#   inflating: data/train/1_242.jpg
#   inflating: data/train/3_192.jpg
#   inflating: data/train/3_22.jpg
#   inflating: data/train/5_896.jpg
#   inflating: data/train/5_128.jpg
#   inflating: data/train/3_804.jpg
#   inflating: data/train/8_679.jpg
#   inflating: data/train/2_1145.jpg
#   inflating: data/train/2_1151.jpg
#   inflating: data/train/3_810.jpg
#   inflating: data/train/4_449.jpg
#   inflating: data/train/3_36.jpg
#   inflating: data/train/5_882.jpg
#   inflating: data/train/9_318.jpg
#   inflating: data/train/5_1281.jpg
#   inflating: data/train/9_287.jpg
#   inflating: data/train/7_4.jpg
#   inflating: data/train/2_222.jpg
#   inflating: data/train/0_694.jpg
#   inflating: data/train/2_544.jpg
#   inflating: data/train/3_757.jpg
#   inflating: data/train/6_160.jpg
#   inflating: data/train/10_96.jpg
#   inflating: data/train/0_680.jpg
#   inflating: data/train/2_550.jpg
#   inflating: data/train/3_743.jpg
#   inflating: data/train/0_858.jpg
#   inflating: data/train/6_174.jpg
#   inflating: data/train/10_82.jpg
#   inflating: data/train/5_909.jpg
#   inflating: data/train/2_236.jpg
#   inflating: data/train/5_1295.jpg
#   inflating: data/train/9_293.jpg
#   inflating: data/train/9_1146.jpg
#   inflating: data/train/5_921.jpg
#   inflating: data/train/10_186.jpg
#   inflating: data/train/2_578.jpg
#   inflating: data/train/0_870.jpg
#   inflating: data/train/4_298.jpg
#   inflating: data/train/0_864.jpg
#   inflating: data/train/6_148.jpg
#   inflating: data/train/10_192.jpg
#   inflating: data/train/9_1152.jpg
#   inflating: data/train/5_935.jpg
#   inflating: data/train/1_322.jpg
#   inflating: data/train/0_131.jpg
#   inflating: data/train/5_706.jpg
#   inflating: data/train/4_515.jpg
#   inflating: data/train/5_1242.jpg
#   inflating: data/train/6_12.jpg
#   inflating: data/train/9_244.jpg
#   inflating: data/train/10_179.jpg
#   inflating: data/train/9_522.jpg
#   inflating: data/train/8_731.jpg
#   inflating: data/train/4_273.jpg
#   inflating: data/train/10_55.jpg
#   inflating: data/train/0_657.jpg
#   inflating: data/train/2_587.jpg
#   inflating: data/train/3_794.jpg
#   inflating: data/train/4_267.jpg
#   inflating: data/train/10_41.jpg
#   inflating: data/train/3_958.jpg
#   inflating: data/train/0_643.jpg
#   inflating: data/train/2_593.jpg
#   inflating: data/train/3_780.jpg
#   inflating: data/train/2_1019.jpg
#   inflating: data/train/9_536.jpg
#   inflating: data/train/8_725.jpg
#   inflating: data/train/5_1256.jpg
#   inflating: data/train/9_250.jpg
#   inflating: data/train/1_336.jpg
#   inflating: data/train/0_125.jpg
#   inflating: data/train/5_712.jpg
#   inflating: data/train/4_501.jpg
#   inflating: data/train/9_278.jpg
#   inflating: data/train/10_145.jpg
#   inflating: data/train/4_529.jpg
#   inflating: data/train/9_1185.jpg
#   inflating: data/train/3_970.jpg
#   inflating: data/train/10_69.jpg
#   inflating: data/train/10_623.jpg
#   inflating: data/train/2_1031.jpg
#   inflating: data/train/1_27.jpg
#   inflating: data/train/2_1025.jpg
#   inflating: data/train/10_637.jpg
#   inflating: data/train/1_33.jpg
#   inflating: data/train/8_719.jpg
#   inflating: data/train/3_964.jpg
#   inflating: data/train/0_119.jpg
#   inflating: data/train/9_1191.jpg
#   inflating: data/train/10_151.jpg
#   inflating: data/train/8_17.jpg
#   inflating: data/train/7_171.jpg
#   inflating: data/train/6_362.jpg
#   inflating: data/train/3_555.jpg
#   inflating: data/train/2_746.jpg
#   inflating: data/train/0_496.jpg
#   inflating: data/train/3_233.jpg
#   inflating: data/train/9_1378.jpg
#   inflating: data/train/6_404.jpg
#   inflating: data/train/5_6.jpg
#   inflating: data/train/8_296.jpg
#   inflating: data/train/5_1083.jpg
#   inflating: data/train/8_282.jpg
#   inflating: data/train/5_1097.jpg
#   inflating: data/train/3_227.jpg
#   inflating: data/train/6_410.jpg
#   inflating: data/train/7_165.jpg
#   inflating: data/train/6_376.jpg
#   inflating: data/train/3_541.jpg
#   inflating: data/train/2_752.jpg
#   inflating: data/train/0_482.jpg
#   inflating: data/train/5_80.jpg
#   inflating: data/train/9_1422.jpg
#   inflating: data/train/3_569.jpg
#   inflating: data/train/9_907.jpg
#   inflating: data/train/10_384.jpg
#   inflating: data/train/6_438.jpg
#   inflating: data/train/9_1344.jpg
#   inflating: data/train/2_89.jpg
#   inflating: data/train/9_1350.jpg
#   inflating: data/train/10_390.jpg
#   inflating: data/train/9_913.jpg
#   inflating: data/train/7_159.jpg
#   inflating: data/train/5_289.jpg
#   inflating: data/train/9_1436.jpg
#   inflating: data/train/5_94.jpg
#   inflating: data/train/3_596.jpg
#   inflating: data/train/2_785.jpg
#   inflating: data/train/0_455.jpg
#   inflating: data/train/5_262.jpg
#   inflating: data/train/8_533.jpg
#   inflating: data/train/9_720.jpg
#   inflating: data/train/8_255.jpg
#   inflating: data/train/5_1040.jpg
#   inflating: data/train/4_717.jpg
#   inflating: data/train/2_76.jpg
#   inflating: data/train/5_504.jpg
#   inflating: data/train/0_333.jpg
#   inflating: data/train/1_120.jpg
#   inflating: data/train/4_703.jpg
#   inflating: data/train/5_510.jpg
#   inflating: data/train/2_62.jpg
#   inflating: data/train/0_327.jpg
#   inflating: data/train/1_134.jpg
#   inflating: data/train/8_241.jpg
#   inflating: data/train/5_1054.jpg
#   inflating: data/train/8_527.jpg
#   inflating: data/train/9_734.jpg
#   inflating: data/train/10_409.jpg
#   inflating: data/train/3_582.jpg
#   inflating: data/train/2_791.jpg
#   inflating: data/train/0_441.jpg
#   inflating: data/train/5_276.jpg
#   inflating: data/train/2_949.jpg
#   inflating: data/train/2_1233.jpg
#   inflating: data/train/10_421.jpg
#   inflating: data/train/0_469.jpg
#   inflating: data/train/5_43.jpg
#   inflating: data/train/2_961.jpg
#   inflating: data/train/9_1387.jpg
#   inflating: data/train/5_538.jpg
#   inflating: data/train/10_347.jpg
#   inflating: data/train/8_269.jpg
#   inflating: data/train/10_353.jpg
#   inflating: data/train/5_1068.jpg
#   inflating: data/train/9_1393.jpg
#   inflating: data/train/1_108.jpg
#   inflating: data/train/5_57.jpg
#   inflating: data/train/6_389.jpg
#   inflating: data/train/2_975.jpg
#   inflating: data/train/9_708.jpg
#   inflating: data/train/10_435.jpg
#   inflating: data/train/2_1227.jpg
#   inflating: data/train/10_345.jpg
#   inflating: data/train/2_48.jpg
#   inflating: data/train/9_1385.jpg
#   inflating: data/train/4_729.jpg
#   inflating: data/train/5_41.jpg
#   inflating: data/train/2_963.jpg
#   inflating: data/train/10_423.jpg
#   inflating: data/train/2_1231.jpg
#   inflating: data/train/2_1225.jpg
#   inflating: data/train/10_437.jpg
#   inflating: data/train/8_519.jpg
#   inflating: data/train/5_55.jpg
#   inflating: data/train/2_977.jpg
#   inflating: data/train/7_198.jpg
#   inflating: data/train/5_248.jpg
#   inflating: data/train/0_319.jpg
#   inflating: data/train/9_1391.jpg
#   inflating: data/train/10_351.jpg
#   inflating: data/train/1_122.jpg
#   inflating: data/train/0_331.jpg
#   inflating: data/train/5_506.jpg
#   inflating: data/train/2_74.jpg
#   inflating: data/train/4_715.jpg
#   inflating: data/train/8_257.jpg
#   inflating: data/train/5_1042.jpg
#   inflating: data/train/10_379.jpg
#   inflating: data/train/9_722.jpg
#   inflating: data/train/8_531.jpg
#   inflating: data/train/5_260.jpg
#   inflating: data/train/2_787.jpg
#   inflating: data/train/0_457.jpg
#   inflating: data/train/3_594.jpg
#   inflating: data/train/5_69.jpg
#   inflating: data/train/5_274.jpg
#   inflating: data/train/2_793.jpg
#   inflating: data/train/0_443.jpg
#   inflating: data/train/3_580.jpg
#   inflating: data/train/2_1219.jpg
#   inflating: data/train/9_736.jpg
#   inflating: data/train/8_525.jpg
#   inflating: data/train/8_243.jpg
#   inflating: data/train/5_1056.jpg
#   inflating: data/train/1_136.jpg
#   inflating: data/train/0_325.jpg
#   inflating: data/train/2_60.jpg
#   inflating: data/train/5_512.jpg
#   inflating: data/train/4_701.jpg
#   inflating: data/train/9_1346.jpg
#   inflating: data/train/10_386.jpg
#   inflating: data/train/9_905.jpg
#   inflating: data/train/2_778.jpg
#   inflating: data/train/9_1420.jpg
#   inflating: data/train/5_82.jpg
#   inflating: data/train/5_96.jpg
#   inflating: data/train/6_348.jpg
#   inflating: data/train/9_1434.jpg
#   inflating: data/train/9_911.jpg
#   inflating: data/train/10_392.jpg
#   inflating: data/train/9_1352.jpg
#   inflating: data/train/3_219.jpg
#   inflating: data/train/8_294.jpg
#   inflating: data/train/5_1081.jpg
#   inflating: data/train/5_4.jpg
#   inflating: data/train/6_406.jpg
#   inflating: data/train/3_231.jpg
#   inflating: data/train/2_744.jpg
#   inflating: data/train/0_494.jpg
#   inflating: data/train/3_557.jpg
#   inflating: data/train/6_360.jpg
#   inflating: data/train/7_173.jpg
#   inflating: data/train/9_939.jpg
#   inflating: data/train/2_750.jpg
#   inflating: data/train/0_480.jpg
#   inflating: data/train/3_543.jpg
#   inflating: data/train/2_988.jpg
#   inflating: data/train/9_1408.jpg
#   inflating: data/train/6_374.jpg
#   inflating: data/train/7_167.jpg
#   inflating: data/train/6_412.jpg
#   inflating: data/train/3_225.jpg
#   inflating: data/train/8_280.jpg
#   inflating: data/train/5_1095.jpg
#   inflating: data/train/1_25.jpg
#   inflating: data/train/2_1033.jpg
#   inflating: data/train/10_621.jpg
#   inflating: data/train/0_669.jpg
#   inflating: data/train/3_972.jpg
#   inflating: data/train/9_1187.jpg
#   inflating: data/train/5_738.jpg
#   inflating: data/train/10_147.jpg
#   inflating: data/train/10_153.jpg
#   inflating: data/train/8_15.jpg
#   inflating: data/train/6_38.jpg
#   inflating: data/train/5_1268.jpg
#   inflating: data/train/9_1193.jpg
#   inflating: data/train/1_308.jpg
#   inflating: data/train/3_966.jpg
#   inflating: data/train/4_259.jpg
#   inflating: data/train/6_189.jpg
#   inflating: data/train/9_508.jpg
#   inflating: data/train/1_31.jpg
#   inflating: data/train/10_635.jpg
#   inflating: data/train/2_1027.jpg
#   inflating: data/train/3_796.jpg
#   inflating: data/train/0_655.jpg
#   inflating: data/train/2_585.jpg
#   inflating: data/train/10_57.jpg
#   inflating: data/train/4_271.jpg
#   inflating: data/train/8_733.jpg
#   inflating: data/train/1_19.jpg
#   inflating: data/train/9_520.jpg
#   inflating: data/train/9_246.jpg
#   inflating: data/train/5_1240.jpg
#   inflating: data/train/6_10.jpg
#   inflating: data/train/4_517.jpg
#   inflating: data/train/5_704.jpg
#   inflating: data/train/0_133.jpg
#   inflating: data/train/1_320.jpg
#   inflating: data/train/4_503.jpg
#   inflating: data/train/5_710.jpg
#   inflating: data/train/9_9.jpg
#   inflating: data/train/0_127.jpg
#   inflating: data/train/1_334.jpg
#   inflating: data/train/8_29.jpg
#   inflating: data/train/9_252.jpg
#   inflating: data/train/5_1254.jpg
#   inflating: data/train/8_727.jpg
#   inflating: data/train/9_534.jpg
#   inflating: data/train/10_609.jpg
#   inflating: data/train/3_782.jpg
#   inflating: data/train/0_641.jpg
#   inflating: data/train/2_591.jpg
#   inflating: data/train/10_43.jpg
#   inflating: data/train/0_899.jpg
#   inflating: data/train/4_265.jpg
#   inflating: data/train/0_872.jpg
#   inflating: data/train/3_769.jpg
#   inflating: data/train/10_184.jpg
#   inflating: data/train/5_923.jpg
#   inflating: data/train/9_1144.jpg
#   inflating: data/train/2_208.jpg
#   inflating: data/train/5_937.jpg
#   inflating: data/train/9_1150.jpg
#   inflating: data/train/10_190.jpg
#   inflating: data/train/0_866.jpg
#   inflating: data/train/10_94.jpg
#   inflating: data/train/6_162.jpg
#   inflating: data/train/3_755.jpg
#   inflating: data/train/0_696.jpg
#   inflating: data/train/2_546.jpg
#   inflating: data/train/2_220.jpg
#   inflating: data/train/7_6.jpg
#   inflating: data/train/9_1178.jpg
#   inflating: data/train/9_285.jpg
#   inflating: data/train/5_1283.jpg
#   inflating: data/train/9_291.jpg
#   inflating: data/train/5_1297.jpg
#   inflating: data/train/2_234.jpg
#   inflating: data/train/10_80.jpg
#   inflating: data/train/6_176.jpg
#   inflating: data/train/3_741.jpg
#   inflating: data/train/0_682.jpg
#   inflating: data/train/2_552.jpg
#   inflating: data/train/2_1147.jpg
#   inflating: data/train/9_468.jpg
#   inflating: data/train/4_339.jpg
#   inflating: data/train/3_806.jpg
#   inflating: data/train/4_29.jpg
#   inflating: data/train/5_894.jpg
#   inflating: data/train/1_268.jpg
#   inflating: data/train/3_20.jpg
#   inflating: data/train/5_1308.jpg
#   inflating: data/train/8_109.jpg
#   inflating: data/train/5_880.jpg
#   inflating: data/train/3_34.jpg
#   inflating: data/train/5_658.jpg
#   inflating: data/train/3_812.jpg
#   inflating: data/train/0_709.jpg
#   inflating: data/train/2_1153.jpg
#   inflating: data/train/4_305.jpg
#   inflating: data/train/5_116.jpg
#   inflating: data/train/0_721.jpg
#   inflating: data/train/4_15.jpg
#   inflating: data/train/9_454.jpg
#   inflating: data/train/8_647.jpg
#   inflating: data/train/8_121.jpg
#   inflating: data/train/9_332.jpg
#   inflating: data/train/1_254.jpg
#   inflating: data/train/3_184.jpg
#   inflating: data/train/2_397.jpg
#   inflating: data/train/5_670.jpg
#   inflating: data/train/4_463.jpg
#   inflating: data/train/1_240.jpg
#   inflating: data/train/3_190.jpg
#   inflating: data/train/2_383.jpg
#   inflating: data/train/5_664.jpg
#   inflating: data/train/4_477.jpg
#   inflating: data/train/5_1320.jpg
#   inflating: data/train/8_135.jpg
#   inflating: data/train/9_326.jpg
#   inflating: data/train/9_440.jpg
#   inflating: data/train/8_653.jpg
#   inflating: data/train/4_311.jpg
#   inflating: data/train/5_102.jpg
#   inflating: data/train/0_735.jpg
#   inflating: data/train/0_906.jpg
#   inflating: data/train/7_239.jpg
#   inflating: data/train/2_1184.jpg
#   inflating: data/train/9_1030.jpg
#   inflating: data/train/5_857.jpg
#   inflating: data/train/2_368.jpg
#   inflating: data/train/4_488.jpg
#   inflating: data/train/9_1024.jpg
#   inflating: data/train/5_843.jpg
#   inflating: data/train/2_1190.jpg
#   inflating: data/train/3_609.jpg
#   inflating: data/train/0_912.jpg
#   inflating: data/train/9_497.jpg
#   inflating: data/train/8_684.jpg
#   inflating: data/train/2_432.jpg
#   inflating: data/train/3_621.jpg
#   inflating: data/train/7_205.jpg
#   inflating: data/train/1_297.jpg
#   inflating: data/train/3_147.jpg
#   inflating: data/train/2_354.jpg
#   inflating: data/train/9_1018.jpg
#   inflating: data/train/1_283.jpg
#   inflating: data/train/3_153.jpg
#   inflating: data/train/2_340.jpg
#   inflating: data/train/2_426.jpg
#   inflating: data/train/3_635.jpg
#   inflating: data/train/1_0.jpg
#   inflating: data/train/7_211.jpg
#   inflating: data/train/9_483.jpg
#   inflating: data/train/8_690.jpg
#   inflating: data/train/8_848.jpg
#   inflating: data/train/10_231.jpg
#   inflating: data/train/2_1423.jpg
#   inflating: data/train/7_44.jpg
#   inflating: data/train/9_69.jpg
#   inflating: data/train/0_279.jpg
#   inflating: data/train/5_328.jpg
#   inflating: data/train/2_817.jpg
#   inflating: data/train/8_479.jpg
#   inflating: data/train/2_1345.jpg
#   inflating: data/train/10_557.jpg
#   inflating: data/train/0_59.jpg
#   inflating: data/train/10_543.jpg
#   inflating: data/train/2_1351.jpg
#   inflating: data/train/2_803.jpg
#   inflating: data/train/4_649.jpg
#   inflating: data/train/2_1437.jpg
#   inflating: data/train/10_225.jpg
#   inflating: data/train/7_50.jpg
#   inflating: data/train/9_118.jpg
#   inflating: data/train/4_661.jpg
#   inflating: data/train/5_472.jpg
#   inflating: data/train/2_195.jpg
#   inflating: data/train/0_245.jpg
#   inflating: data/train/3_386.jpg
#   inflating: data/train/7_78.jpg
#   inflating: data/train/9_130.jpg
#   inflating: data/train/8_323.jpg
#   inflating: data/train/5_1136.jpg
#   inflating: data/train/9_55.jpg
#   inflating: data/train/8_445.jpg
#   inflating: data/train/9_656.jpg
#   inflating: data/train/0_71.jpg
#   inflating: data/train/2_1379.jpg
#   inflating: data/train/0_523.jpg
#   inflating: data/train/5_314.jpg
#   inflating: data/train/4_107.jpg
#   inflating: data/train/0_537.jpg
#   inflating: data/train/5_300.jpg
#   inflating: data/train/4_113.jpg
#   inflating: data/train/8_451.jpg
#   inflating: data/train/9_642.jpg
#   inflating: data/train/0_65.jpg
#   inflating: data/train/10_219.jpg
#   inflating: data/train/9_124.jpg
#   inflating: data/train/8_337.jpg
#   inflating: data/train/9_41.jpg
#   inflating: data/train/5_1122.jpg
#   inflating: data/train/4_675.jpg
#   inflating: data/train/5_466.jpg
#   inflating: data/train/2_181.jpg
#   inflating: data/train/0_251.jpg
#   inflating: data/train/3_392.jpg
#   inflating: data/train/4_846.jpg
#   inflating: data/train/3_379.jpg
#   inflating: data/train/9_1232.jpg
#   inflating: data/train/7_87.jpg
#   inflating: data/train/2_1386.jpg
#   inflating: data/train/10_594.jpg
#   inflating: data/train/9_871.jpg
#   inflating: data/train/6_228.jpg
#   inflating: data/train/2_618.jpg
#   inflating: data/train/10_580.jpg
#   inflating: data/train/2_1392.jpg
#   inflating: data/train/9_865.jpg
#   inflating: data/train/7_93.jpg
#   inflating: data/train/9_1226.jpg
#   inflating: data/train/5_499.jpg
#   inflating: data/train/9_96.jpg
#   inflating: data/train/2_156.jpg
#   inflating: data/train/0_286.jpg
#   inflating: data/train/3_345.jpg
#   inflating: data/train/6_214.jpg
#   inflating: data/train/3_423.jpg
#   inflating: data/train/2_630.jpg
#   inflating: data/train/8_486.jpg
#   inflating: data/train/9_695.jpg
#   inflating: data/train/9_859.jpg
#   inflating: data/train/8_492.jpg
#   inflating: data/train/9_681.jpg
#   inflating: data/train/3_2.jpg
#   inflating: data/train/6_200.jpg
#   inflating: data/train/3_437.jpg
#   inflating: data/train/2_624.jpg
#   inflating: data/train/2_142.jpg
#   inflating: data/train/0_292.jpg
#   inflating: data/train/3_351.jpg
#   inflating: data/train/9_82.jpg
#   inflating: data/train/2_625.jpg
#   inflating: data/train/3_436.jpg
#   inflating: data/train/6_201.jpg
#   inflating: data/train/3_3.jpg
#   inflating: data/train/9_680.jpg
#   inflating: data/train/8_493.jpg
#   inflating: data/train/9_858.jpg
#   inflating: data/train/9_83.jpg
#   inflating: data/train/3_350.jpg
#   inflating: data/train/0_293.jpg
#   inflating: data/train/2_143.jpg
#   inflating: data/train/3_344.jpg
#   inflating: data/train/0_287.jpg
#   inflating: data/train/2_157.jpg
#   inflating: data/train/9_97.jpg
#   inflating: data/train/9_694.jpg
#   inflating: data/train/8_487.jpg
#   inflating: data/train/2_631.jpg
#   inflating: data/train/3_422.jpg
#   inflating: data/train/6_215.jpg
#   inflating: data/train/9_864.jpg
#   inflating: data/train/2_1393.jpg
#   inflating: data/train/10_581.jpg
#   inflating: data/train/2_619.jpg
#   inflating: data/train/5_498.jpg
#   inflating: data/train/9_1227.jpg
#   inflating: data/train/7_92.jpg
#   inflating: data/train/7_86.jpg
#   inflating: data/train/9_1233.jpg
#   inflating: data/train/3_378.jpg
#   inflating: data/train/4_847.jpg
#   inflating: data/train/6_229.jpg
#   inflating: data/train/9_870.jpg
#   inflating: data/train/10_595.jpg
#   inflating: data/train/2_1387.jpg
#   inflating: data/train/0_64.jpg
#   inflating: data/train/9_643.jpg
#   inflating: data/train/8_450.jpg
#   inflating: data/train/4_112.jpg
#   inflating: data/train/5_301.jpg
#   inflating: data/train/0_536.jpg
#   inflating: data/train/3_393.jpg
#   inflating: data/train/0_250.jpg
#   inflating: data/train/2_180.jpg
#   inflating: data/train/5_467.jpg
#   inflating: data/train/4_674.jpg
#   inflating: data/train/5_1123.jpg
#   inflating: data/train/9_40.jpg
#   inflating: data/train/8_336.jpg
#   inflating: data/train/9_125.jpg
#   inflating: data/train/10_218.jpg
#   inflating: data/train/9_54.jpg
#   inflating: data/train/5_1137.jpg
#   inflating: data/train/8_322.jpg
#   inflating: data/train/9_131.jpg
#   inflating: data/train/7_79.jpg
#   inflating: data/train/3_387.jpg
#   inflating: data/train/0_244.jpg
#   inflating: data/train/2_194.jpg
#   inflating: data/train/5_473.jpg
#   inflating: data/train/4_660.jpg
#   inflating: data/train/4_106.jpg
#   inflating: data/train/5_315.jpg
#   inflating: data/train/0_522.jpg
#   inflating: data/train/2_1378.jpg
#   inflating: data/train/0_70.jpg
#   inflating: data/train/9_657.jpg
#   inflating: data/train/8_444.jpg
#   inflating: data/train/2_802.jpg
#   inflating: data/train/2_1350.jpg
#   inflating: data/train/10_542.jpg
#   inflating: data/train/0_58.jpg
#   inflating: data/train/9_119.jpg
#   inflating: data/train/7_51.jpg
#   inflating: data/train/10_224.jpg
#   inflating: data/train/2_1436.jpg
#   inflating: data/train/4_648.jpg
#   inflating: data/train/0_278.jpg
#   inflating: data/train/9_68.jpg
#   inflating: data/train/7_45.jpg
#   inflating: data/train/2_1422.jpg
#   inflating: data/train/10_230.jpg
#   inflating: data/train/10_556.jpg
#   inflating: data/train/2_1344.jpg
#   inflating: data/train/8_478.jpg
#   inflating: data/train/2_816.jpg
#   inflating: data/train/5_329.jpg
#   inflating: data/train/2_341.jpg
#   inflating: data/train/3_152.jpg
#   inflating: data/train/1_282.jpg
#   inflating: data/train/9_1019.jpg
#   inflating: data/train/8_849.jpg
#   inflating: data/train/8_691.jpg
#   inflating: data/train/9_482.jpg
#   inflating: data/train/7_210.jpg
#   inflating: data/train/1_1.jpg
#   inflating: data/train/3_634.jpg
#   inflating: data/train/2_427.jpg
#   inflating: data/train/7_204.jpg
#   inflating: data/train/3_620.jpg
#   inflating: data/train/2_433.jpg
#   inflating: data/train/8_685.jpg
#   inflating: data/train/9_496.jpg
#   inflating: data/train/2_355.jpg
#   inflating: data/train/3_146.jpg
#   inflating: data/train/1_296.jpg
#   inflating: data/train/5_842.jpg
#   inflating: data/train/9_1025.jpg
#   inflating: data/train/4_489.jpg
#   inflating: data/train/0_913.jpg
#   inflating: data/train/3_608.jpg
#   inflating: data/train/2_1191.jpg
#   inflating: data/train/2_1185.jpg
#   inflating: data/train/7_238.jpg
#   inflating: data/train/0_907.jpg
#   inflating: data/train/2_369.jpg
#   inflating: data/train/5_856.jpg
#   inflating: data/train/9_1031.jpg
#   inflating: data/train/9_327.jpg
#   inflating: data/train/8_134.jpg
#   inflating: data/train/5_1321.jpg
#   inflating: data/train/4_476.jpg
#   inflating: data/train/5_665.jpg
#   inflating: data/train/2_382.jpg
#   inflating: data/train/3_191.jpg
#   inflating: data/train/1_241.jpg
#   inflating: data/train/0_734.jpg
#   inflating: data/train/5_103.jpg
#   inflating: data/train/4_310.jpg
#   inflating: data/train/8_652.jpg
#   inflating: data/train/9_441.jpg
#   inflating: data/train/8_646.jpg
#   inflating: data/train/9_455.jpg
#   inflating: data/train/4_14.jpg
#   inflating: data/train/0_720.jpg
#   inflating: data/train/5_117.jpg
#   inflating: data/train/4_304.jpg
#   inflating: data/train/4_462.jpg
#   inflating: data/train/5_671.jpg
#   inflating: data/train/2_396.jpg
#   inflating: data/train/3_185.jpg
#   inflating: data/train/1_255.jpg
#   inflating: data/train/9_333.jpg
#   inflating: data/train/8_120.jpg
#   inflating: data/train/5_659.jpg
#   inflating: data/train/3_35.jpg
#   inflating: data/train/5_881.jpg
#   inflating: data/train/8_108.jpg
#   inflating: data/train/2_1152.jpg
#   inflating: data/train/0_708.jpg
#   inflating: data/train/3_813.jpg
#   inflating: data/train/4_28.jpg
#   inflating: data/train/3_807.jpg
#   inflating: data/train/4_338.jpg
#   inflating: data/train/9_469.jpg
#   inflating: data/train/2_1146.jpg
#   inflating: data/train/5_1309.jpg
#   inflating: data/train/3_21.jpg
#   inflating: data/train/1_269.jpg
#   inflating: data/train/5_895.jpg
#   inflating: data/train/2_235.jpg
#   inflating: data/train/5_1296.jpg
#   inflating: data/train/9_290.jpg
#   inflating: data/train/2_553.jpg
#   inflating: data/train/0_683.jpg
#   inflating: data/train/3_740.jpg
#   inflating: data/train/6_177.jpg
#   inflating: data/train/10_81.jpg
#   inflating: data/train/2_547.jpg
#   inflating: data/train/0_697.jpg
#   inflating: data/train/3_754.jpg
#   inflating: data/train/6_163.jpg
#   inflating: data/train/10_95.jpg
#   inflating: data/train/5_1282.jpg
#   inflating: data/train/9_284.jpg
#   inflating: data/train/9_1179.jpg
#   inflating: data/train/7_7.jpg
#   inflating: data/train/2_221.jpg
#   inflating: data/train/10_191.jpg
#   inflating: data/train/9_1151.jpg
#   inflating: data/train/5_936.jpg
#   inflating: data/train/2_209.jpg
#   inflating: data/train/0_867.jpg
#   inflating: data/train/3_768.jpg
#   inflating: data/train/0_873.jpg
#   inflating: data/train/9_1145.jpg
#   inflating: data/train/5_922.jpg
#   inflating: data/train/10_185.jpg
#   inflating: data/train/5_1255.jpg
#   inflating: data/train/9_253.jpg
#   inflating: data/train/8_28.jpg
#   inflating: data/train/1_335.jpg
#   inflating: data/train/0_126.jpg
#   inflating: data/train/9_8.jpg
#   inflating: data/train/5_711.jpg
#   inflating: data/train/4_502.jpg
#   inflating: data/train/4_264.jpg
#   inflating: data/train/0_898.jpg
#   inflating: data/train/10_42.jpg
#   inflating: data/train/2_590.jpg
#   inflating: data/train/0_640.jpg
#   inflating: data/train/3_783.jpg
#   inflating: data/train/10_608.jpg
#   inflating: data/train/9_535.jpg
#   inflating: data/train/8_726.jpg
#   inflating: data/train/9_521.jpg
#   inflating: data/train/1_18.jpg
#   inflating: data/train/8_732.jpg
#   inflating: data/train/4_270.jpg
#   inflating: data/train/10_56.jpg
#   inflating: data/train/2_584.jpg
#   inflating: data/train/0_654.jpg
#   inflating: data/train/3_797.jpg
#   inflating: data/train/1_321.jpg
#   inflating: data/train/0_132.jpg
#   inflating: data/train/5_705.jpg
#   inflating: data/train/4_516.jpg
#   inflating: data/train/6_11.jpg
#   inflating: data/train/5_1241.jpg
#   inflating: data/train/9_247.jpg
#   inflating: data/train/1_309.jpg
#   inflating: data/train/9_1192.jpg
#   inflating: data/train/5_1269.jpg
#   inflating: data/train/6_39.jpg
#   inflating: data/train/10_152.jpg
#   inflating: data/train/8_14.jpg
#   inflating: data/train/2_1026.jpg
#   inflating: data/train/10_634.jpg
#   inflating: data/train/1_30.jpg
#   inflating: data/train/9_509.jpg
#   inflating: data/train/6_188.jpg
#   inflating: data/train/4_258.jpg
#   inflating: data/train/3_967.jpg
#   inflating: data/train/3_973.jpg
#   inflating: data/train/0_668.jpg
#   inflating: data/train/10_620.jpg
#   inflating: data/train/2_1032.jpg
#   inflating: data/train/1_24.jpg
#   inflating: data/train/10_146.jpg
#   inflating: data/train/5_739.jpg
#   inflating: data/train/9_1186.jpg
#   inflating: data/train/7_166.jpg
#   inflating: data/train/6_375.jpg
#   inflating: data/train/9_1409.jpg
#   inflating: data/train/2_989.jpg
#   inflating: data/train/3_542.jpg
#   inflating: data/train/0_481.jpg
#   inflating: data/train/2_751.jpg
#   inflating: data/train/5_1094.jpg
#   inflating: data/train/8_281.jpg
#   inflating: data/train/3_224.jpg
#   inflating: data/train/6_413.jpg
#   inflating: data/train/3_230.jpg
#   inflating: data/train/6_407.jpg
#   inflating: data/train/5_5.jpg
#   inflating: data/train/5_1080.jpg
#   inflating: data/train/8_295.jpg
#   inflating: data/train/9_938.jpg
#   inflating: data/train/7_172.jpg
#   inflating: data/train/6_361.jpg
#   inflating: data/train/3_556.jpg
#   inflating: data/train/0_495.jpg
#   inflating: data/train/2_745.jpg
#   inflating: data/train/9_910.jpg
#   inflating: data/train/5_97.jpg
#   inflating: data/train/9_1435.jpg
#   inflating: data/train/6_349.jpg
#   inflating: data/train/3_218.jpg
#   inflating: data/train/9_1353.jpg
#   inflating: data/train/10_393.jpg
#   inflating: data/train/10_387.jpg
#   inflating: data/train/9_1347.jpg
#   inflating: data/train/9_1421.jpg
#   inflating: data/train/5_83.jpg
#   inflating: data/train/2_779.jpg
#   inflating: data/train/9_904.jpg
#   inflating: data/train/8_524.jpg
#   inflating: data/train/9_737.jpg
#   inflating: data/train/2_1218.jpg
#   inflating: data/train/3_581.jpg
#   inflating: data/train/0_442.jpg
#   inflating: data/train/2_792.jpg
#   inflating: data/train/5_275.jpg
#   inflating: data/train/5_68.jpg
#   inflating: data/train/4_700.jpg
#   inflating: data/train/5_513.jpg
#   inflating: data/train/2_61.jpg
#   inflating: data/train/0_324.jpg
#   inflating: data/train/1_137.jpg
#   inflating: data/train/5_1057.jpg
#   inflating: data/train/8_242.jpg
#   inflating: data/train/10_378.jpg
#   inflating: data/train/5_1043.jpg
#   inflating: data/train/8_256.jpg
#   inflating: data/train/4_714.jpg
#   inflating: data/train/2_75.jpg
#   inflating: data/train/5_507.jpg
#   inflating: data/train/0_330.jpg
#   inflating: data/train/1_123.jpg
#   inflating: data/train/3_595.jpg
#   inflating: data/train/0_456.jpg
#   inflating: data/train/2_786.jpg
#   inflating: data/train/5_261.jpg
#   inflating: data/train/8_530.jpg
#   inflating: data/train/9_723.jpg
#   inflating: data/train/5_249.jpg
#   inflating: data/train/7_199.jpg
#   inflating: data/train/2_976.jpg
#   inflating: data/train/5_54.jpg
#   inflating: data/train/8_518.jpg
#   inflating: data/train/10_436.jpg
#   inflating: data/train/2_1224.jpg
#   inflating: data/train/10_350.jpg
#   inflating: data/train/9_1390.jpg
#   inflating: data/train/0_318.jpg
#   inflating: data/train/4_728.jpg
#   inflating: data/train/9_1384.jpg
#   inflating: data/train/2_49.jpg
#   inflating: data/train/10_344.jpg
#   inflating: data/train/2_1230.jpg
#   inflating: data/train/10_422.jpg
#   inflating: data/train/2_962.jpg
#   inflating: data/train/5_40.jpg
#   inflating: data/train/2_1208.jpg
#   inflating: data/train/8_534.jpg
#   inflating: data/train/9_727.jpg
#   inflating: data/train/5_265.jpg
#   inflating: data/train/5_78.jpg
#   inflating: data/train/3_591.jpg
#   inflating: data/train/2_782.jpg
#   inflating: data/train/0_452.jpg
#   inflating: data/train/0_334.jpg
#   inflating: data/train/1_127.jpg
#   inflating: data/train/4_710.jpg
#   inflating: data/train/5_503.jpg
#   inflating: data/train/2_71.jpg
#   inflating: data/train/8_252.jpg
#   inflating: data/train/5_1047.jpg
#   inflating: data/train/8_246.jpg
#   inflating: data/train/5_1053.jpg
#   inflating: data/train/10_368.jpg
#   inflating: data/train/0_320.jpg
#   inflating: data/train/1_133.jpg
#   inflating: data/train/4_704.jpg
#   inflating: data/train/2_65.jpg
#   inflating: data/train/5_517.jpg
#   inflating: data/train/5_271.jpg
#   inflating: data/train/3_585.jpg
#   inflating: data/train/2_796.jpg
#   inflating: data/train/0_446.jpg
#   inflating: data/train/8_520.jpg
#   inflating: data/train/9_733.jpg
#   inflating: data/train/7_189.jpg
#   inflating: data/train/5_259.jpg
#   inflating: data/train/5_44.jpg
#   inflating: data/train/2_966.jpg
#   inflating: data/train/10_426.jpg
#   inflating: data/train/2_1234.jpg
#   inflating: data/train/8_508.jpg
#   inflating: data/train/10_340.jpg
#   inflating: data/train/0_308.jpg
#   inflating: data/train/9_1380.jpg
#   inflating: data/train/9_1394.jpg
#   inflating: data/train/4_738.jpg
#   inflating: data/train/2_59.jpg
#   inflating: data/train/10_354.jpg
#   inflating: data/train/2_1220.jpg
#   inflating: data/train/10_432.jpg
#   inflating: data/train/5_50.jpg
#   inflating: data/train/2_972.jpg
#   inflating: data/train/3_552.jpg
#   inflating: data/train/2_741.jpg
#   inflating: data/train/0_491.jpg
#   inflating: data/train/7_176.jpg
#   inflating: data/train/2_999.jpg
#   inflating: data/train/9_1419.jpg
#   inflating: data/train/6_365.jpg
#   inflating: data/train/8_291.jpg
#   inflating: data/train/5_1084.jpg
#   inflating: data/train/5_1.jpg
#   inflating: data/train/6_403.jpg
#   inflating: data/train/3_234.jpg
#   inflating: data/train/6_417.jpg
#   inflating: data/train/3_220.jpg
#   inflating: data/train/8_285.jpg
#   inflating: data/train/5_1090.jpg
#   inflating: data/train/9_928.jpg
#   inflating: data/train/3_546.jpg
#   inflating: data/train/2_755.jpg
#   inflating: data/train/0_485.jpg
#   inflating: data/train/7_162.jpg
#   inflating: data/train/6_371.jpg
#   inflating: data/train/9_900.jpg
#   inflating: data/train/5_87.jpg
#   inflating: data/train/6_359.jpg
#   inflating: data/train/9_1425.jpg
#   inflating: data/train/9_1343.jpg
#   inflating: data/train/3_208.jpg
#   inflating: data/train/10_383.jpg
#   inflating: data/train/10_397.jpg
#   inflating: data/train/9_1357.jpg
#   inflating: data/train/2_769.jpg
#   inflating: data/train/9_1431.jpg
#   inflating: data/train/5_93.jpg
#   inflating: data/train/9_914.jpg
#   inflating: data/train/8_38.jpg
#   inflating: data/train/5_1245.jpg
#   inflating: data/train/6_15.jpg
#   inflating: data/train/9_243.jpg
#   inflating: data/train/5_701.jpg
#   inflating: data/train/4_512.jpg
#   inflating: data/train/1_325.jpg
#   inflating: data/train/0_136.jpg
#   inflating: data/train/0_650.jpg
#   inflating: data/train/2_580.jpg
#   inflating: data/train/3_793.jpg
#   inflating: data/train/0_888.jpg
#   inflating: data/train/4_274.jpg
#   inflating: data/train/10_52.jpg
#   inflating: data/train/9_525.jpg
#   inflating: data/train/8_736.jpg
#   inflating: data/train/10_618.jpg
#   inflating: data/train/9_531.jpg
#   inflating: data/train/8_722.jpg
#   inflating: data/train/0_644.jpg
#   inflating: data/train/2_594.jpg
#   inflating: data/train/3_787.jpg
#   inflating: data/train/4_260.jpg
#   inflating: data/train/10_46.jpg
#   inflating: data/train/5_715.jpg
#   inflating: data/train/4_506.jpg
#   inflating: data/train/1_331.jpg
#   inflating: data/train/0_122.jpg
#   inflating: data/train/5_1251.jpg
#   inflating: data/train/9_257.jpg
#   inflating: data/train/9_1182.jpg
#   inflating: data/train/1_319.jpg
#   inflating: data/train/10_142.jpg
#   inflating: data/train/6_29.jpg
#   inflating: data/train/5_1279.jpg
#   inflating: data/train/9_519.jpg
#   inflating: data/train/1_20.jpg
#   inflating: data/train/2_1036.jpg
#   inflating: data/train/10_624.jpg
#   inflating: data/train/4_248.jpg
#   inflating: data/train/6_198.jpg
#   inflating: data/train/3_977.jpg
#   inflating: data/train/0_678.jpg
#   inflating: data/train/3_963.jpg
#   inflating: data/train/1_34.jpg
#   inflating: data/train/10_630.jpg
#   inflating: data/train/2_1022.jpg
# ...
#   inflating: data/train/2_319.jpg
#   inflating: data/train/5_826.jpg
#   inflating: data/train/9_1055.jpg
#   inflating: data/train/3_86.jpg
#   inflating: data/train/5_832.jpg
#   inflating: data/train/8_805.jpg
#   inflating: data/train/3_678.jpg
#   inflating: data/train/0_963.jpg
#   inflating: data/train/5_403.jpg
#   inflating: data/train/4_610.jpg
#   inflating: data/train/0_234.jpg
#   inflating: data/train/8_352.jpg
#   inflating: data/train/5_1147.jpg
#   inflating: data/train/9_24.jpg
#   inflating: data/train/9_141.jpg
#   inflating: data/train/9_627.jpg
#   inflating: data/train/8_434.jpg
#   inflating: data/train/2_1308.jpg
#   inflating: data/train/2_682.jpg
#   inflating: data/train/0_552.jpg
#   inflating: data/train/3_491.jpg
#   inflating: data/train/4_176.jpg
#   inflating: data/train/5_365.jpg
#   inflating: data/train/2_696.jpg
#   inflating: data/train/0_546.jpg
#   inflating: data/train/3_485.jpg
#   inflating: data/train/4_162.jpg
#   inflating: data/train/5_371.jpg
#   inflating: data/train/9_633.jpg
#   inflating: data/train/8_420.jpg
#   inflating: data/train/0_14.jpg
#   inflating: data/train/10_268.jpg
#   inflating: data/train/8_346.jpg
#   inflating: data/train/9_30.jpg
#   inflating: data/train/5_1153.jpg
#   inflating: data/train/9_155.jpg
#   inflating: data/train/5_417.jpg
#   inflating: data/train/4_604.jpg
#   inflating: data/train/0_220.jpg
#   inflating: data/train/10_240.jpg
#   inflating: data/train/2_1452.jpg
#   inflating: data/train/7_35.jpg
#   inflating: data/train/9_18.jpg
#   inflating: data/train/9_1280.jpg
#   inflating: data/train/0_208.jpg
#   inflating: data/train/2_866.jpg
#   inflating: data/train/5_359.jpg
#   inflating: data/train/8_408.jpg
#   inflating: data/train/2_1334.jpg
#   inflating: data/train/10_526.jpg
#   inflating: data/train/10_532.jpg
#   inflating: data/train/2_1320.jpg
#   inflating: data/train/0_28.jpg
#   inflating: data/train/2_872.jpg
#   inflating: data/train/9_1294.jpg
#   inflating: data/train/4_638.jpg
#   inflating: data/train/2_1446.jpg
#   inflating: data/train/10_254.jpg
#   inflating: data/train/7_21.jpg
#   inflating: data/train/9_169.jpg
#   inflating: data/train/8_391.jpg
#   inflating: data/train/5_1184.jpg
#   inflating: data/train/9_182.jpg
#   inflating: data/train/3_334.jpg
#   inflating: data/train/2_127.jpg
#   inflating: data/train/4_1.jpg
#   inflating: data/train/2_899.jpg
#   inflating: data/train/6_265.jpg
#   inflating: data/train/2_641.jpg
#   inflating: data/train/0_591.jpg
#   inflating: data/train/3_452.jpg
#   inflating: data/train/9_828.jpg
#   inflating: data/train/6_271.jpg
#   inflating: data/train/2_655.jpg
#   inflating: data/train/0_585.jpg
#   inflating: data/train/3_446.jpg
#   inflating: data/train/3_320.jpg
#   inflating: data/train/2_133.jpg
#   inflating: data/train/8_385.jpg
#   inflating: data/train/5_1190.jpg
#   inflating: data/train/9_196.jpg
#   inflating: data/train/3_308.jpg
#   inflating: data/train/4_837.jpg
#   inflating: data/train/9_1243.jpg
#   inflating: data/train/10_283.jpg
#   inflating: data/train/2_1491.jpg
#   inflating: data/train/9_800.jpg
#   inflating: data/train/6_259.jpg
#   inflating: data/train/4_189.jpg
#   inflating: data/train/2_669.jpg
#   inflating: data/train/9_814.jpg
#   inflating: data/train/2_1485.jpg
#   inflating: data/train/10_297.jpg
#   inflating: data/train/4_823.jpg
#   inflating: data/train/9_1257.jpg
#   inflating: data/train/9_815.jpg
#   inflating: data/train/2_668.jpg
#   inflating: data/train/9_1256.jpg
#   inflating: data/train/4_822.jpg
#   inflating: data/train/10_296.jpg
#   inflating: data/train/2_1484.jpg
#   inflating: data/train/2_1490.jpg
#   inflating: data/train/10_282.jpg
#   inflating: data/train/9_1242.jpg
#   inflating: data/train/4_836.jpg
#   inflating: data/train/3_309.jpg
#   inflating: data/train/4_188.jpg
#   inflating: data/train/6_258.jpg
#   inflating: data/train/9_801.jpg
#   inflating: data/train/3_447.jpg
#   inflating: data/train/0_584.jpg
#   inflating: data/train/2_654.jpg
#   inflating: data/train/6_270.jpg
#   inflating: data/train/9_829.jpg
#   inflating: data/train/9_197.jpg
#   inflating: data/train/5_1191.jpg
#   inflating: data/train/8_384.jpg
#   inflating: data/train/2_132.jpg
#   inflating: data/train/3_321.jpg
#   inflating: data/train/4_0.jpg
#   inflating: data/train/2_126.jpg
#   inflating: data/train/3_335.jpg
#   inflating: data/train/9_183.jpg
#   inflating: data/train/5_1185.jpg
#   inflating: data/train/8_390.jpg
#   inflating: data/train/3_453.jpg
#   inflating: data/train/0_590.jpg
#   inflating: data/train/2_640.jpg
#   inflating: data/train/6_264.jpg
#   inflating: data/train/2_898.jpg
#   inflating: data/train/2_873.jpg
#   inflating: data/train/0_29.jpg
#   inflating: data/train/2_1321.jpg
#   inflating: data/train/10_533.jpg
#   inflating: data/train/9_168.jpg
#   inflating: data/train/7_20.jpg
#   inflating: data/train/10_255.jpg
#   inflating: data/train/2_1447.jpg
#   inflating: data/train/4_639.jpg
#   inflating: data/train/9_1295.jpg
#   inflating: data/train/0_209.jpg
#   inflating: data/train/9_1281.jpg
#   inflating: data/train/9_19.jpg
#   inflating: data/train/7_34.jpg
#   inflating: data/train/2_1453.jpg
#   inflating: data/train/10_241.jpg
#   inflating: data/train/10_527.jpg
#   inflating: data/train/2_1335.jpg
#   inflating: data/train/8_409.jpg
#   inflating: data/train/5_358.jpg
#   inflating: data/train/2_867.jpg
#   inflating: data/train/0_15.jpg
#   inflating: data/train/8_421.jpg
#   inflating: data/train/9_632.jpg
#   inflating: data/train/5_370.jpg
#   inflating: data/train/4_163.jpg
#   inflating: data/train/3_484.jpg
#   inflating: data/train/0_547.jpg
#   inflating: data/train/2_697.jpg
#   inflating: data/train/0_221.jpg
#   inflating: data/train/4_605.jpg
#   inflating: data/train/5_416.jpg
#   inflating: data/train/9_154.jpg
#   inflating: data/train/5_1152.jpg
#   inflating: data/train/9_31.jpg
#   inflating: data/train/8_347.jpg
#   inflating: data/train/10_269.jpg
#   inflating: data/train/9_140.jpg
#   inflating: data/train/9_25.jpg
#   inflating: data/train/5_1146.jpg
#   inflating: data/train/8_353.jpg
#   inflating: data/train/0_235.jpg
#   inflating: data/train/4_611.jpg
#   inflating: data/train/5_402.jpg
#   inflating: data/train/5_364.jpg
#   inflating: data/train/4_177.jpg
#   inflating: data/train/3_490.jpg
#   inflating: data/train/0_553.jpg
#   inflating: data/train/2_683.jpg
#   inflating: data/train/2_1309.jpg
#   inflating: data/train/8_435.jpg
#   inflating: data/train/9_626.jpg
#   inflating: data/train/5_833.jpg
#   inflating: data/train/3_87.jpg
#   inflating: data/train/9_1054.jpg
#   inflating: data/train/0_962.jpg
#   inflating: data/train/3_679.jpg
#   inflating: data/train/8_804.jpg
#   inflating: data/train/8_810.jpg
#   inflating: data/train/0_976.jpg
#   inflating: data/train/7_249.jpg
#   inflating: data/train/5_199.jpg
#   inflating: data/train/5_827.jpg
#   inflating: data/train/2_318.jpg
#   inflating: data/train/3_93.jpg
#   inflating: data/train/9_1040.jpg
#   inflating: data/train/3_123.jpg
#   inflating: data/train/2_330.jpg
#   inflating: data/train/9_1068.jpg
#   inflating: data/train/8_186.jpg
#   inflating: data/train/9_395.jpg
#   inflating: data/train/8_838.jpg
#   inflating: data/train/7_261.jpg
#   inflating: data/train/2_456.jpg
#   inflating: data/train/0_786.jpg
#   inflating: data/train/3_645.jpg
#   inflating: data/train/3_889.jpg
#   inflating: data/train/7_275.jpg
#   inflating: data/train/2_442.jpg
#   inflating: data/train/0_792.jpg
#   inflating: data/train/3_651.jpg
#   inflating: data/train/8_192.jpg
#   inflating: data/train/9_381.jpg
#   inflating: data/train/3_137.jpg
#   inflating: data/train/2_324.jpg
#   inflating: data/train/6_2.jpg
#   inflating: data/train/5_628.jpg
#   inflating: data/train/9_1097.jpg
#   inflating: data/train/3_44.jpg
#   inflating: data/train/8_179.jpg
#   inflating: data/train/2_1123.jpg
#   inflating: data/train/0_779.jpg
#   inflating: data/train/3_862.jpg
#   inflating: data/train/4_59.jpg
#   inflating: data/train/4_349.jpg
#   inflating: data/train/3_876.jpg
#   inflating: data/train/9_418.jpg
#   inflating: data/train/2_1137.jpg
#   inflating: data/train/9_1083.jpg
#   inflating: data/train/1_218.jpg
#   inflating: data/train/3_50.jpg
#   inflating: data/train/8_145.jpg
#   inflating: data/train/9_356.jpg
#   inflating: data/train/5_614.jpg
#   inflating: data/train/4_407.jpg
#   inflating: data/train/1_230.jpg
#   inflating: data/train/3_78.jpg
#   inflating: data/train/2_495.jpg
#   inflating: data/train/0_745.jpg
#   inflating: data/train/3_686.jpg
#   inflating: data/train/4_71.jpg
#   inflating: data/train/4_361.jpg
#   inflating: data/train/5_172.jpg
#   inflating: data/train/9_430.jpg
#   inflating: data/train/8_623.jpg
#   inflating: data/train/9_424.jpg
#   inflating: data/train/8_637.jpg
#   inflating: data/train/2_481.jpg
#   inflating: data/train/0_751.jpg
#   inflating: data/train/3_692.jpg
#   inflating: data/train/4_65.jpg
#   inflating: data/train/4_375.jpg
#   inflating: data/train/0_989.jpg
#   inflating: data/train/5_166.jpg
#   inflating: data/train/5_600.jpg
#   inflating: data/train/4_413.jpg
#   inflating: data/train/1_224.jpg
#   inflating: data/train/8_151.jpg
#   inflating: data/train/9_342.jpg
#   inflating: data/train/9_1120.jpg
#   inflating: data/train/2_278.jpg
#   inflating: data/train/5_947.jpg
#   inflating: data/train/0_816.jpg
#   inflating: data/train/1_82.jpg
#   inflating: data/train/2_1094.jpg
#   inflating: data/train/10_686.jpg
#   inflating: data/train/1_96.jpg
#   inflating: data/train/10_692.jpg
#   inflating: data/train/2_1080.jpg
#   inflating: data/train/3_719.jpg
#   inflating: data/train/0_802.jpg
#   inflating: data/train/9_1134.jpg
#   inflating: data/train/4_598.jpg
#   inflating: data/train/5_953.jpg
#   inflating: data/train/2_244.jpg
#   inflating: data/train/0_194.jpg
#   inflating: data/train/1_387.jpg
#   inflating: data/train/8_794.jpg
#   inflating: data/train/9_587.jpg
#   inflating: data/train/3_731.jpg
#   inflating: data/train/2_522.jpg
#   inflating: data/train/0_4.jpg
#   inflating: data/train/6_106.jpg
#   inflating: data/train/3_725.jpg
#   inflating: data/train/2_536.jpg
#   inflating: data/train/6_112.jpg
#   inflating: data/train/8_780.jpg
#   inflating: data/train/9_593.jpg
#   inflating: data/train/9_1108.jpg
#   inflating: data/train/2_250.jpg
#   inflating: data/train/0_180.jpg
#   inflating: data/train/1_393.jpg
#   inflating: data/train/1_378.jpg
#   inflating: data/train/5_984.jpg
#   inflating: data/train/5_1218.jpg
#   inflating: data/train/6_48.jpg
#   inflating: data/train/10_123.jpg
#   inflating: data/train/8_65.jpg
#   inflating: data/train/2_1057.jpg
#   inflating: data/train/10_645.jpg
#   inflating: data/train/1_41.jpg
#   inflating: data/train/9_578.jpg
#   inflating: data/train/3_916.jpg
#   inflating: data/train/4_229.jpg
#   inflating: data/train/3_902.jpg
#   inflating: data/train/0_619.jpg
#   inflating: data/train/10_651.jpg
#   inflating: data/train/2_1043.jpg
#   inflating: data/train/1_55.jpg
#   inflating: data/train/10_137.jpg
#   inflating: data/train/8_71.jpg
#   inflating: data/train/5_990.jpg
#   inflating: data/train/5_748.jpg
#   inflating: data/train/9_222.jpg
#   inflating: data/train/6_74.jpg
#   inflating: data/train/5_1224.jpg
#   inflating: data/train/8_59.jpg
#   inflating: data/train/2_287.jpg
#   inflating: data/train/0_157.jpg
#   inflating: data/train/1_344.jpg
#   inflating: data/train/4_573.jpg
#   inflating: data/train/5_760.jpg
#   inflating: data/train/10_33.jpg
#   inflating: data/train/4_215.jpg
#   inflating: data/train/1_422.jpg
#   inflating: data/train/0_631.jpg
#   inflating: data/train/10_679.jpg
#   inflating: data/train/8_757.jpg
#   inflating: data/train/9_544.jpg
#   inflating: data/train/8_743.jpg
#   inflating: data/train/9_550.jpg
#   inflating: data/train/1_69.jpg
#   inflating: data/train/10_27.jpg
#   inflating: data/train/4_201.jpg
#   inflating: data/train/0_625.jpg
#   inflating: data/train/2_293.jpg
#   inflating: data/train/0_143.jpg
#   inflating: data/train/1_350.jpg
#   inflating: data/train/4_567.jpg
#   inflating: data/train/5_774.jpg
#   inflating: data/train/9_236.jpg
#   inflating: data/train/6_60.jpg
#   inflating: data/train/5_1230.jpg
#   inflating: data/train/9_961.jpg
#   inflating: data/train/10_484.jpg
#   inflating: data/train/2_1296.jpg
#   inflating: data/train/9_1444.jpg
#   inflating: data/train/6_338.jpg
#   inflating: data/train/3_269.jpg
#   inflating: data/train/9_1322.jpg
#   inflating: data/train/5_589.jpg
#   inflating: data/train/9_1336.jpg
#   inflating: data/train/9_1450.jpg
#   inflating: data/train/2_708.jpg
#   inflating: data/train/9_975.jpg
#   inflating: data/train/2_1282.jpg
#   inflating: data/train/10_490.jpg
#   inflating: data/train/2_6.jpg
#   inflating: data/train/6_304.jpg
#   inflating: data/train/9_1478.jpg
#   inflating: data/train/7_117.jpg
#   inflating: data/train/2_720.jpg
#   inflating: data/train/3_533.jpg
#   inflating: data/train/9_785.jpg
#   inflating: data/train/8_596.jpg
#   inflating: data/train/1_185.jpg
#   inflating: data/train/3_255.jpg
#   inflating: data/train/0_396.jpg
#   inflating: data/train/1_191.jpg
#   inflating: data/train/3_241.jpg
#   inflating: data/train/0_382.jpg
#   inflating: data/train/9_949.jpg
#   inflating: data/train/9_791.jpg
#   inflating: data/train/8_582.jpg
#   inflating: data/train/6_310.jpg
#   inflating: data/train/7_103.jpg
#   inflating: data/train/2_734.jpg
#   inflating: data/train/3_527.jpg
#   inflating: data/train/2_907.jpg
#   inflating: data/train/9_1487.jpg
#   inflating: data/train/5_25.jpg
#   inflating: data/train/5_238.jpg
#   inflating: data/train/8_569.jpg
#   inflating: data/train/10_447.jpg
#   inflating: data/train/2_1255.jpg
#   inflating: data/train/10_321.jpg
#   inflating: data/train/0_369.jpg
#   inflating: data/train/2_38.jpg
#   inflating: data/train/4_759.jpg
#   inflating: data/train/10_335.jpg
#   inflating: data/train/2_1241.jpg
#   inflating: data/train/10_453.jpg
#   inflating: data/train/2_913.jpg
#   inflating: data/train/5_31.jpg
#   inflating: data/train/9_1493.jpg
#   inflating: data/train/9_746.jpg
#   inflating: data/train/8_555.jpg
#   inflating: data/train/2_1269.jpg
#   inflating: data/train/0_433.jpg
#   inflating: data/train/5_19.jpg
#   inflating: data/train/5_204.jpg
#   inflating: data/train/5_562.jpg
#   inflating: data/train/2_10.jpg
#   inflating: data/train/4_771.jpg
#   inflating: data/train/1_146.jpg
#   inflating: data/train/3_296.jpg
#   inflating: data/train/0_355.jpg
#   inflating: data/train/5_1026.jpg
#   inflating: data/train/8_233.jpg
#   inflating: data/train/10_309.jpg
#   inflating: data/train/5_1032.jpg
#   inflating: data/train/8_227.jpg
#   inflating: data/train/5_576.jpg
#   inflating: data/train/4_765.jpg
#   inflating: data/train/1_152.jpg
#   inflating: data/train/3_282.jpg
#   inflating: data/train/0_341.jpg
#   inflating: data/train/0_427.jpg
#   inflating: data/train/5_210.jpg
#   inflating: data/train/9_752.jpg
#   inflating: data/train/8_541.jpg

# %% [markdown]
# # Import Packages

# %%
_exp_name = "sample"

# %%
# Import necessary packages.
import numpy as np
import pandas as pd
import torch
import os
import torch.nn as nn
from torchvision.transforms import v2
from PIL import Image
# "ConcatDataset" and "Subset" are possibly useful when doing semi-supervised learning.
from torch.utils.data import ConcatDataset, DataLoader, Subset, Dataset
from sklearn.model_selection import KFold
from torchvision.datasets import DatasetFolder, VisionDataset
# This is for the progress bar.
from tqdm.auto import tqdm
import random

# %%
def same_seeds(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

seed = 1213
same_seeds(seed)

# %% [markdown]
# # Transforms
# Torchvision provides lots of useful utilities for image preprocessing, data *wrapping* as well as data augmentation.
#
# Please refer to PyTorch official website for details about different transforms.

# %%
# Normally, We don't need augmentations in testing and validation.
# All we need here is to resize the PIL image and transform it into Tensor.
test_tfm = v2.Compose([
    v2.Resize((128, 128)),
    v2.ToTensor(),
])

# However, it is also possible to use augmentation in the testing phase.
# You may use train_tfm to produce a variety of images and then test using ensemble methods
train_tfm = v2.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    v2.RandomResizedCrop((128,128), scale=(0.08, 1.0), ratio=(0.75, 1.3333333333333333), interpolation=v2.InterpolationMode.BICUBIC),
    # You may add some transforms here.
    v2.Pad(2, fill=255),
    v2.RandomPerspective(distortion_scale=0.5, p=0.5, interpolation=v2.InterpolationMode.BILINEAR, fill=0),
    # ToTensor() should be the last one of the transforms.
    v2.ToTensor(),
    v2.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225]),
])
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %% [markdown]
# # Datasets
# The data is labelled by the name, so we load images and label while calling '__getitem__'

# %%
class FoodDataset(Dataset):

    def __init__(self,path,tfm=test_tfm,files = None):
        super(FoodDataset).__init__()
        self.path = path
        self.files = sorted([os.path.join(path,x) for x in os.listdir(path) if x.endswith(".jpg")])
        if files != None:
            self.files = files

        self.transform = tfm

    def __len__(self):
        return len(self.files)

    def __getitem__(self,idx):
        fname = self.files[idx]
        im = Image.open(fname)
        im = self.transform(im)

        try:
            label = int(fname.split("/")[-1].split("_")[0])
        except:
            label = -1 # test has no label

        return im,label

# %% [markdown]
# # Model

# %%
class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        # torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
        # torch.nn.MaxPool2d(kernel_size, stride, padding)
        # input dimension [3, 128, 128]
        self.cnn = nn.Sequential(
            nn.Conv2d(3, 64, 3, 1, 1),  # [64, 128, 128]
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2, 0),      # [64, 64, 64]

            nn.Conv2d(64, 128, 3, 1, 1), # [128, 64, 64]
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2, 0),      # [128, 32, 32]

            nn.Conv2d(128, 256, 3, 1, 1), # [256, 32, 32]
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2, 2, 0),      # [256, 16, 16]

            nn.Conv2d(256, 512, 3, 1, 1), # [512, 16, 16]
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2, 2, 0),       # [512, 8, 8]

            nn.Conv2d(512, 512, 3, 1, 1), # [512, 8, 8]
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2, 2, 0),       # [512, 4, 4]
        )
        self.fc = nn.Sequential(
            nn.Linear(512*4*4, 1024),
            nn.ReLU(),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Linear(512, 11)
        )

    def forward(self, x):
        out = self.cnn(x)
        out = out.view(out.size()[0], -1)
        return self.fc(out)

# %% [markdown]
# # Configurations

# %%
# "cuda" only when GPUs are available.
device = "cuda" if torch.cuda.is_available() else "cpu"

# Initialize a model, and put it on the device specified.
model = Classifier().to(device)

# The number of batch size.
batch_size = 64

# The number of training epochs.
n_epochs = 3

# If no improvement in 'patience' epochs, early stop.
patience = 5

# For the classification task, we use cross-entropy as the measurement of performance.
criterion = nn.CrossEntropyLoss()

# Initialize optimizer, you may fine-tune some hyperparameters such as learning rate on your own.
optimizer = torch.optim.Adam(model.parameters(), lr=0.0003, weight_decay=1e-5)

# %% [markdown]
# # Dataloader

# %%
# Construct train and valid datasets.
# The argument "loader" tells how torchvision reads the data.
train_set = FoodDataset("./data/train", tfm=train_tfm)
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)
valid_set = FoodDataset("./data/valid", tfm=test_tfm)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)

# %% [markdown]
# # Start Training

# %%
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Initialize trackers, these are not parameters and should not be changed
stale = 0
best_acc = 0

for train_index, valid_index in kfold.split(train_set):  # Iterate over folds

    # Create train and validation subsets
    train_subset = Subset(train_set, train_index)
    valid_subset = Subset(train_set, valid_index)

    # Create DataLoaders for train and validation subsets
    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    valid_loader = DataLoader(valid_subset, batch_size=batch_size, shuffle=False)

    # Reset model state (optional)
    model.load_state_dict(model.state_dict())

    for epoch in range(n_epochs):

      # ---------- Training ----------
      # Make sure the model is in train mode before training.
      model.train()

      # These are used to record information in training.
      train_loss = []
      train_accs = []

      for batch in tqdm(train_loader):

          # A batch consists of image data and corresponding labels.
          imgs, labels = batch
          #imgs = imgs.half()
          #print(imgs.shape,labels.shape)

          # Forward the data. (Make sure data and model are on the same device.)
          logits = model(imgs.to(device))

          # Calculate the cross-entropy loss.
          # We don't need to apply softmax before computing cross-entropy as it is done automatically.
          loss = criterion(logits, labels.to(device))

          # Gradients stored in the parameters in the previous step should be cleared out first.
          optimizer.zero_grad()

          # Compute the gradients for parameters.
          loss.backward()

          # Clip the gradient norms for stable training.
          grad_norm = nn.utils.clip_grad_norm_(model.parameters(), max_norm=10)

          # Update the parameters with computed gradients.
          optimizer.step()

          # Compute the accuracy for current batch.
          acc = (logits.argmax(dim=-1) == labels.to(device)).float().mean()

          # Record the loss and accuracy.
          train_loss.append(loss.item())
          train_accs.append(acc)

      train_loss = sum(train_loss) / len(train_loss)
      train_acc = sum(train_accs) / len(train_accs)

      # Print the information.
      print(f"[ Train | {epoch + 1:03d}/{n_epochs:03d} ] loss = {train_loss:.5f}, acc = {train_acc:.5f}")

      # ---------- Validation ----------
      # Make sure the model is in eval mode so that some modules like dropout are disabled and work normally.
      model.eval()

      # These are used to record information in validation.
      valid_loss = []
      valid_accs = []

      # Iterate the validation set by batches.
      for batch in tqdm(valid_loader):

          # A batch consists of image data and corresponding labels.
          imgs, labels = batch
          #imgs = imgs.half()

          # We don't need gradient in validation.
          # Using torch.no_grad() accelerates the forward process.
          with torch.no_grad():
              logits = model(imgs.to(device))

          # We can still compute the loss (but not the gradient).
          loss = criterion(logits, labels.to(device))

          # Compute the accuracy for current batch.
          acc = (logits.argmax(dim=-1) == labels.to(device)).float().mean()

          # Record the loss and accuracy.
          valid_loss.append(loss.item())
          valid_accs.append(acc)
          #break

      # The average loss and accuracy for entire validation set is the average of the recorded values.
      valid_loss = sum(valid_loss) / len(valid_loss)
      valid_acc = sum(valid_accs) / len(valid_accs)

      # Print the information.
      print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f}")


      # update logs
      if valid_acc > best_acc:
          with open(f"./{_exp_name}_log.txt","a"):
              print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f} -> best")
      else:
          with open(f"./{_exp_name}_log.txt","a"):
              print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f}")


      # save models
      if valid_acc > best_acc:
          print(f"Best model found at epoch {epoch}, saving model")
          torch.save(model.state_dict(), f"{_exp_name}_best.ckpt") # only save best to prevent output memory exceed error
          best_acc = valid_acc
          stale = 0
      else:
          stale += 1
          if stale > patience:
              print(f"No improvment {patience} consecutive epochs, early stopping")
              break
# Out:
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 001/003 ] loss = 1.71786, acc = 0.39428
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 001/003 ] loss = 1.75713, acc = 0.39378
# [ Valid | 001/003 ] loss = 1.75713, acc = 0.39378 -> best
# Best model found at epoch 0, saving model
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 002/003 ] loss = 1.65701, acc = 0.41757
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 002/003 ] loss = 1.96574, acc = 0.36214
# [ Valid | 002/003 ] loss = 1.96574, acc = 0.36214
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 003/003 ] loss = 1.62120, acc = 0.43700
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 003/003 ] loss = 1.68678, acc = 0.41514
# [ Valid | 003/003 ] loss = 1.68678, acc = 0.41514 -> best
# Best model found at epoch 2, saving model
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 001/003 ] loss = 1.56543, acc = 0.45381
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 001/003 ] loss = 1.63454, acc = 0.45235
# [ Valid | 001/003 ] loss = 1.63454, acc = 0.45235 -> best
# Best model found at epoch 0, saving model
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 002/003 ] loss = 1.51749, acc = 0.47156
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 002/003 ] loss = 1.56738, acc = 0.45218
# [ Valid | 002/003 ] loss = 1.56738, acc = 0.45218
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 003/003 ] loss = 1.45645, acc = 0.49830
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 003/003 ] loss = 1.63253, acc = 0.44658
# [ Valid | 003/003 ] loss = 1.63253, acc = 0.44658
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 001/003 ] loss = 1.44808, acc = 0.50158
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 001/003 ] loss = 1.43564, acc = 0.49480
# [ Valid | 001/003 ] loss = 1.43564, acc = 0.49480 -> best
# Best model found at epoch 0, saving model
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 002/003 ] loss = 1.39241, acc = 0.52389
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 002/003 ] loss = 1.45551, acc = 0.48623
# [ Valid | 002/003 ] loss = 1.45551, acc = 0.48623
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 003/003 ] loss = 1.34409, acc = 0.54189
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 003/003 ] loss = 1.41692, acc = 0.50983
# [ Valid | 003/003 ] loss = 1.41692, acc = 0.50983 -> best
# Best model found at epoch 2, saving model
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 001/003 ] loss = 1.35426, acc = 0.53169
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 001/003 ] loss = 1.43508, acc = 0.52556
# [ Valid | 001/003 ] loss = 1.43508, acc = 0.52556 -> best
# Best model found at epoch 0, saving model
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 002/003 ] loss = 1.30024, acc = 0.55035
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 002/003 ] loss = 1.42828, acc = 0.51044
# [ Valid | 002/003 ] loss = 1.42828, acc = 0.51044
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 003/003 ] loss = 1.27505, acc = 0.56875
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 003/003 ] loss = 1.38690, acc = 0.52603
# [ Valid | 003/003 ] loss = 1.38690, acc = 0.52603 -> best
# Best model found at epoch 2, saving model
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 001/003 ] loss = 1.26530, acc = 0.56773
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 001/003 ] loss = 1.27537, acc = 0.56912
# [ Valid | 001/003 ] loss = 1.27537, acc = 0.56912 -> best
# Best model found at epoch 0, saving model
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 002/003 ] loss = 1.24447, acc = 0.57644
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 002/003 ] loss = 1.22924, acc = 0.58514
# [ Valid | 002/003 ] loss = 1.22924, acc = 0.58514 -> best
# Best model found at epoch 1, saving model
#   0%|          | 0/124 [00:00<?, ?it/s]
# [ Train | 003/003 ] loss = 1.20475, acc = 0.58438
#   0%|          | 0/31 [00:00<?, ?it/s]
# [ Valid | 003/003 ] loss = 1.27508, acc = 0.56236
# [ Valid | 003/003 ] loss = 1.27508, acc = 0.56236

# %% [markdown]
# # Dataloader for test

# %%
# Construct test datasets.
# The argument "loader" tells how torchvision reads the data.
test_set = FoodDataset("./data/test", tfm=test_tfm)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

# %% [markdown]
# # Testing and generate prediction CSV

# %%
model_best = Classifier().to(device)
model_best.load_state_dict(torch.load(f"{_exp_name}_best.ckpt"))
model_best.eval()
prediction = []
with torch.no_grad():
    for data,_ in tqdm(test_loader):
        test_pred = model_best(data.to(device))
        test_label = np.argmax(test_pred.cpu().data.numpy(), axis=1)
        prediction += test_label.squeeze().tolist()
# Out:
# <ipython-input-48-b23ababdbf1e>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model_best.load_state_dict(torch.load(f"{_exp_name}_best.ckpt"))
#   0%|          | 0/24 [00:00<?, ?it/s]

# %%
# create test csv
def pad4(i):
    return "0"*(4-len(str(i)))+str(i)
df = pd.DataFrame()
df["Id"] = [pad4(i) for i in range(len(test_set))]
df["Label"] = prediction
df.to_csv("submission.csv",index = False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.to_csv('/content/drive/MyDrive/submission.csv', index=False)
